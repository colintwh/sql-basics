# %% [markdown]
# # Querying Data
#
# One of the most common tasks, when you work with the database, is to query data from tables by using the `select` statement. The `select` statement has many clauses that you can use to form a flexible query. While only one of them is mandatory when using the `select` clause, you will usually include at least two or three of the available clauses. Table below shows some of the different clauses and their purpose:
#
# **Clause name** | **Purpose**
# --- | ---
# `Select` | Determines which columns to include in the query's result set
# `From` | Identifies the tables from which to draw data and how the tables should be joined
# `Where` | Filters out unwanted data
# `Group by` | Used to group rows together by common column values
# `Having` | Filter out unwanted groups
# `Order by` | Sorts the rows of the final result set by one or more columns
#
# ***Note:*** *I have typed out SQL clauses in CAPITAL LETTERS in the examples but it is not always required to have them in CAPS. This is just to help you easily distinguish the SQL keywords from object references (tables, columns, etc.) in the statement/code. PostgreSQL and some other databases do accept SQL keywords in small letters.*
#
# The following sections delve into the uses of the six major query clauses
#
# ## The `select` Clause
#
#    Albeit the `select` clause is the first clause of a SQL query statement, it is one of the last clauses that the database server evaluates. The reason for this is that before you can determine what to include in the final result set, you need to know all of the possible columns that could be included in the final result set. The `select` clause is typically paired with `from` clause. Here's a query to get started:

# %% [markdown]
# *Initial setup to load sql module in order to run sql statements on this Notebook:*

# %% [markdown]
# ***Note:*** *Each cell demonstrating SQL code in Jupyter Notebook needs to begin with `%%sql` in order for the interpreter to treat the code as SQL statements/queries. The `%%sql` is not needed otherwise in SQL/database-client tools.*
#
# *Initial setup to load sql module in order to run sql statements on this Notebook:*

# %%
# %load_ext sql
# %sql postgresql://postgres:password@localhost/dvdrental

# %%
# %%sql
#
# SELECT * FROM category;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 16 rows affected.
# [(1, 'Action', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (2, 'Animation', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (3, 'Children', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (4, 'Classics', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (5, 'Comedy', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (6, 'Documentary', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (7, 'Drama', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (8, 'Family', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (9, 'Foreign', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (10, 'Games', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (11, 'Horror', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (12, 'Music', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (13, 'New', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (14, 'Sci-Fi', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (15, 'Sports', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (16, 'Travel', datetime.datetime(2006, 2, 15, 9, 46, 27))]

# %% [markdown]
# In this query, the `from` clause lists a single table (`actor`), and the `select` clause indicates that all columns (designed by \*) in the `actor` table should be included in the result set. Basically the query statement could be described in English as follows:
#
# > *Show me all columns and all rows in the **`actor`** table*
#
# Also note that each SQL statement has to end with a semi-colon. Otherwise the SQL interpreter will continue to expect additional clauses for input.
#
# You can also explicitly name the columns you are interested in the query, such as:

# %%
# %%sql
#
# SELECT category_id, name FROM category;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 16 rows affected.
# [(1, 'Action'),
#  (2, 'Animation'),
#  (3, 'Children'),
#  (4, 'Classics'),
#  (5, 'Comedy'),
#  (6, 'Documentary'),
#  (7, 'Drama'),
#  (8, 'Family'),
#  (9, 'Foreign'),
#  (10, 'Games'),
#  (11, 'Horror'),
#  (12, 'Music'),
#  (13, 'New'),
#  (14, 'Sci-Fi'),
#  (15, 'Sports'),
#  (16, 'Travel')]

# %% [markdown]
#    Thus the `select` clause determines which of all possible columns should be included in the query's result set.
#    Also, it is not a good practice to use the asterisk (*) in the `select` statement when you use the embedded SQL statements in the code due to the following reasons:
#
# + For a large table with many columns, the `select` statement with an asterisk (*) shorthand will retrieve data from all columns of the table, which may not be necessary.
# + In addition, retrieving unnecessary data from the database increases the traffic between the database and application layers. As a result, your applications will be slow and less scalable. Therefore, it is a good practice to specify the column names explicitly in the `select` clause whenever possible to get only necessary data from a table.
#
# Because of these reasons, you should only use the asterisk (\*) shorthand for the ad-hoc queries to examine the data. In cases when you need to select all columns to get a preview of the data, you can use the `limit` clause to limit the rows in the result set to a specific number:

# %%
# %%sql
#
# SELECT * FROM category LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(1, 'Action', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (2, 'Animation', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (3, 'Children', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (4, 'Classics', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (5, 'Comedy', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (6, 'Documentary', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (7, 'Drama', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (8, 'Family', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (9, 'Foreign', datetime.datetime(2006, 2, 15, 9, 46, 27)),
#  (10, 'Games', datetime.datetime(2006, 2, 15, 9, 46, 27))]

# %% [markdown]
# ***Note:*** *The `limit` clause is not a SQL-standard though it is widely used by many relational database management systems such as MySQL, H2, and HSQLDB. Not all database systems support the `limit` clause.*
#
# ***2nd note:*** *I will also be frequently using the `limit` clause in the code examples to avoid displaying too many rows in the results output, thus keeping the learning notes concise.*
#
# The usage of `select` clause is not just limited to columns. You can also use expressions like below:

# %%
# %%sql
#
# SELECT category_id,
# category_id * 3.14159,
# UPPER(name)
# FROM category;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 16 rows affected.
# [(1, Decimal('3.14159'), 'ACTION'),
#  (2, Decimal('6.28318'), 'ANIMATION'),
#  (3, Decimal('9.42477'), 'CHILDREN'),
#  (4, Decimal('12.56636'), 'CLASSICS'),
#  (5, Decimal('15.70795'), 'COMEDY'),
#  (6, Decimal('18.84954'), 'DOCUMENTARY'),
#  (7, Decimal('21.99113'), 'DRAMA'),
#  (8, Decimal('25.13272'), 'FAMILY'),
#  (9, Decimal('28.27431'), 'FOREIGN'),
#  (10, Decimal('31.41590'), 'GAMES'),
#  (11, Decimal('34.55749'), 'HORROR'),
#  (12, Decimal('37.69908'), 'MUSIC'),
#  (13, Decimal('40.84067'), 'NEW'),
#  (14, Decimal('43.98226'), 'SCI-FI'),
#  (15, Decimal('47.12385'), 'SPORTS'),
#  (16, Decimal('50.26544'), 'TRAVEL')]

# %% [markdown]
# For certain built-in function or to evaluate a simple expression, you can skip the `from` clause entirely. For example:

# %%
# %%sql
#
# SELECT NOW();
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 1 rows affected.
# [(datetime.datetime(2020, 6, 14, 17, 12, 27, 876825, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=480, name=None)),)]

# %% [markdown]
# ### Column Aliases
#
# Though SQL query will generate labels for the columns returned, you might still want to assign a new label to a column from a table. In cases where the result set are generated by expressions or built-in function calls, you would almost certainly want to assign your own labels to those columns. You can use the `as` keyword before the alias name like in the example below:

# %%
# %%sql
#
# SELECT category_id,
# category_id * 3.14159 AS category_id_x_pi,
# UPPER(name) AS name_upper
# FROM category;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 16 rows affected.
# [(1, Decimal('3.14159'), 'ACTION'),
#  (2, Decimal('6.28318'), 'ANIMATION'),
#  (3, Decimal('9.42477'), 'CHILDREN'),
#  (4, Decimal('12.56636'), 'CLASSICS'),
#  (5, Decimal('15.70795'), 'COMEDY'),
#  (6, Decimal('18.84954'), 'DOCUMENTARY'),
#  (7, Decimal('21.99113'), 'DRAMA'),
#  (8, Decimal('25.13272'), 'FAMILY'),
#  (9, Decimal('28.27431'), 'FOREIGN'),
#  (10, Decimal('31.41590'), 'GAMES'),
#  (11, Decimal('34.55749'), 'HORROR'),
#  (12, Decimal('37.69908'), 'MUSIC'),
#  (13, Decimal('40.84067'), 'NEW'),
#  (14, Decimal('43.98226'), 'SCI-FI'),
#  (15, Decimal('47.12385'), 'SPORTS'),
#  (16, Decimal('50.26544'), 'TRAVEL')]

# %% [markdown]
# **Note:** The `as` keyword is optional and it is not necessary to use `as` before column aliases. They do help to improve the readability of your SQL codes.

# %% [markdown]
# ### Removing Duplicates
#
# In some cases, a query might return duplicate rows of data like in the example below:

# %%
# %%sql
#
# SELECT category_id FROM film_category LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(6,), (11,), (6,), (11,), (8,), (9,), (5,), (11,), (11,), (15,)]

# %% [markdown]
# You would probably want in this case a distinct set of film categories from the table like this:

# %%
# %%sql
#
# SELECT DISTINCT category_id FROM film_category;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 16 rows affected.
# [(4,),
#  (14,),
#  (3,),
#  (10,),
#  (7,),
#  (13,),
#  (9,),
#  (1,),
#  (5,),
#  (2,),
#  (16,),
#  (15,),
#  (6,),
#  (12,),
#  (8,),
#  (11,)]

# %% [markdown]
# ## The `from` Clause
#
# Thus far, you have seen queries whose `from` clause contain a single table. The role of the `from` clause is that *it defines the tables used by a query, along with the means of linking the tables together*.
#
# ### Tables
#
# When confronted with the term *table*, the general notion is a set of related rows stored in a database. In a relational database system, there are three types of tables:
#
# 1. Permanent tables (i.e. created using the `create table` statement)
# 2. Temporary tables (i.e. rows returned by a subquery)
# 3. Virtual tables (i.e. created using the `create view` statement)
#
# Each of these table types may be included in a query's `from` clause. From the earlier examples, you should be comfortable with including a permanent table in a `from` clause. I will now briefly describe the other types of tables that can be referenced in a `from` clause.
#
# #### Subquery-generated tables
#
# A subquery is a query contained within another query. Subqueries are surrounded by parentheses and can be found in various parts of a `select` statement; within the `from` clause, however, a subquery serves the role of generating a temporary table that is visible from all other query clauses and can interact with other tables named in the `from ` clauses. Here's an example:

# %%
# %%sql
#
# SELECT c.customer_id, c.first_name, c.last_name, c.create_date
# FROM (SELECT customer_id, first_name, last_name, email, create_date
#       FROM customer LIMIT 10) c;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(524, 'Jared', 'Ely', datetime.date(2006, 2, 14)),
#  (1, 'Mary', 'Smith', datetime.date(2006, 2, 14)),
#  (2, 'Patricia', 'Johnson', datetime.date(2006, 2, 14)),
#  (3, 'Linda', 'Williams', datetime.date(2006, 2, 14)),
#  (4, 'Barbara', 'Jones', datetime.date(2006, 2, 14)),
#  (5, 'Elizabeth', 'Brown', datetime.date(2006, 2, 14)),
#  (6, 'Jennifer', 'Davis', datetime.date(2006, 2, 14)),
#  (7, 'Maria', 'Miller', datetime.date(2006, 2, 14)),
#  (8, 'Susan', 'Wilson', datetime.date(2006, 2, 14)),
#  (9, 'Margaret', 'Moore', datetime.date(2006, 2, 14))]

# %% [markdown]
# In the above example, the subquery is referenced by the containing query via its alias, which in this case, is c. This is just an illustration of a simplistic but not particularly useful example of a subquery in a `from` clause.
#
# #### Views
#
# A view is a query that is stored in the data dictionary. It looks and acts like a table, but there is in fact, no data associated with a view (thus, a virtual table). When you issue a query against a view, your query is merged with the view definition to create a final query to be executed. Views are created for various reasons, including for user's convenience or to simplify complex database designs.
#
# To demonstrate, here's an example of a view definition that queries the customer table and included a call to a built-in function to extract just the year from a date column:

# %%
# %%sql
#
# CREATE VIEW customer_vw AS
# SELECT customer_id, first_name, last_name, EXTRACT(YEAR FROM create_date) create_year
# FROM customer;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# Done.
# []

# %% [markdown]
# When the view is created, no additional data is generated or stored; the database server simply tucks away the `select` statement for future use. You can now issue queries against the view, like in the example below:

# %%
# %%sql
#
# SELECT customer_id, create_year
# FROM customer_vw LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(524, 2006.0),
#  (1, 2006.0),
#  (2, 2006.0),
#  (3, 2006.0),
#  (4, 2006.0),
#  (5, 2006.0),
#  (6, 2006.0),
#  (7, 2006.0),
#  (8, 2006.0),
#  (9, 2006.0)]

# %% [markdown]
# ### Table Links
#
# The second deviation fron the simple `from` clause definition is the mandate that if more than one table appears in the `from` clause, the conditions used to *link* the tables must be included as well. Here's a simple illustration:

# %%
# %%sql
#
# SELECT customer.customer_id, customer.first_name, customer.last_name, address.address
# FROM customer INNER JOIN address
# ON customer.address_id = address.address_id LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(1, 'Mary', 'Smith', '1913 Hanoi Way'),
#  (2, 'Patricia', 'Johnson', '1121 Loja Avenue'),
#  (3, 'Linda', 'Williams', '692 Joliet Street'),
#  (4, 'Barbara', 'Jones', '1566 Inegl Manor'),
#  (5, 'Elizabeth', 'Brown', '53 Idfu Parkway'),
#  (6, 'Jennifer', 'Davis', '1795 Santiago de Compostela Way'),
#  (7, 'Maria', 'Miller', '900 Santiago de Compostela Parkway'),
#  (8, 'Susan', 'Wilson', '478 Joliet Way'),
#  (9, 'Margaret', 'Moore', '613 Korolev Drive'),
#  (10, 'Dorothy', 'Taylor', '1531 Sal Drive')]

# %% [markdown]
# The previous query displays data from both the `customer` table and the `address` table, so both tables are included in the `from` clause. The mechanism for linking the two tables (referred to as a *join*) is the customer's address affiliation stored in the `customer` table. Thus the database server is instructed to use the value of the `address_id` column in the `customer` table to look up the associated address name in the `address` table. Join conditions for two tables are found in the `on` subclause of the `from` clause; in this case, the join condition is `ON c.address_id = a.address_id`.
#
# #### Table Aliases
#
# When joining multiple tables in a single query, you need a way to identify which table you are referring to when you reference columns in the `select`, `where`, `group by`, `having`, and `order by` clauses. You have two choices when referencing a table outside the `from` clause:
#
# + Use the entire table name, such as `customer.customer_id`
# + Assign each table an *alias* and use the alias throughout the query
#
# The above query uses the entire table names (i.e. `customer` and `address`). Here's what the same query looks like using table aliases:

# %%
# %%sql
#
# SELECT cust.customer_id, cust.first_name, cust.last_name, addr.address
# FROM customer AS cust INNER JOIN address AS addr
# ON cust.address_id = addr.address_id LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(1, 'Mary', 'Smith', '1913 Hanoi Way'),
#  (2, 'Patricia', 'Johnson', '1121 Loja Avenue'),
#  (3, 'Linda', 'Williams', '692 Joliet Street'),
#  (4, 'Barbara', 'Jones', '1566 Inegl Manor'),
#  (5, 'Elizabeth', 'Brown', '53 Idfu Parkway'),
#  (6, 'Jennifer', 'Davis', '1795 Santiago de Compostela Way'),
#  (7, 'Maria', 'Miller', '900 Santiago de Compostela Parkway'),
#  (8, 'Susan', 'Wilson', '478 Joliet Way'),
#  (9, 'Margaret', 'Moore', '613 Korolev Drive'),
#  (10, 'Dorothy', 'Taylor', '1531 Sal Drive')]

# %% [markdown]
# ***Note:*** *Similar to column aliases, the usage of `as` keyword before each table alias is optional; I used them to enhance readability of the code in the examples. You can choose to omit them and the query statement will still work.*

# %% [markdown]
# ## The `where` clause
#
# The queries shown thus have selected every row from the table (except for the demonstration of `distinct`) in earlier examples. Most of the time, however, you will not wish to retrieve *every* row from a table but will want a way to filter out those rows that are not of interest. This ia a job for the `where` clause.
#
# > *The `where` clause is the mechanism for filtering out unwanted rows from your result set.*
#
# For example, the following query employs a `where` clause to retrieve *only* the non-active customers:

# %%
# %%sql
#
# SELECT customer_id, first_name, last_name, email, active
# FROM customer
# WHERE active = 0;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 15 rows affected.
# [(16, 'Sandra', 'Martin', 'sandra.martin@sakilacustomer.org', 0),
#  (64, 'Judith', 'Cox', 'judith.cox@sakilacustomer.org', 0),
#  (124, 'Sheila', 'Wells', 'sheila.wells@sakilacustomer.org', 0),
#  (169, 'Erica', 'Matthews', 'erica.matthews@sakilacustomer.org', 0),
#  (241, 'Heidi', 'Larson', 'heidi.larson@sakilacustomer.org', 0),
#  (271, 'Penny', 'Neal', 'penny.neal@sakilacustomer.org', 0),
#  (315, 'Kenneth', 'Gooden', 'kenneth.gooden@sakilacustomer.org', 0),
#  (368, 'Harry', 'Arce', 'harry.arce@sakilacustomer.org', 0),
#  (406, 'Nathan', 'Runyon', 'nathan.runyon@sakilacustomer.org', 0),
#  (446, 'Theodore', 'Culp', 'theodore.culp@sakilacustomer.org', 0),
#  (482, 'Maurice', 'Crawley', 'maurice.crawley@sakilacustomer.org', 0),
#  (510, 'Ben', 'Easter', 'ben.easter@sakilacustomer.org', 0),
#  (534, 'Christian', 'Jung', 'christian.jung@sakilacustomer.org', 0),
#  (558, 'Jimmie', 'Eggleston', 'jimmie.eggleston@sakilacustomer.org', 0),
#  (592, 'Terrance', 'Roush', 'terrance.roush@sakilacustomer.org', 0)]

# %% [markdown]
# In this case, the `where` clause contains a single filter condition, but you can include as many conditions as required; individual conditions are separated using operators such as `and`, `or` and `not`. Here's another example of a query that incorporates two filter conditions in the `where` clause:

# %%
# %%sql
#
# SELECT film_id, title, rental_rate, rating
# FROM film
# WHERE rental_rate < 2.0
# AND rating = 'PG-13' LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(18, 'Alter Victory', Decimal('0.99'), 'PG-13'),
#  (36, 'Argonauts Town', Decimal('0.99'), 'PG-13'),
#  (64, 'Beethoven Exorcist', Decimal('0.99'), 'PG-13'),
#  (79, 'Blade Polish', Decimal('0.99'), 'PG-13'),
#  (108, 'Butch Panther', Decimal('0.99'), 'PG-13'),
#  (130, 'Celebrity Horn', Decimal('0.99'), 'PG-13'),
#  (155, 'Cleopatra Devil', Decimal('0.99'), 'PG-13'),
#  (157, 'Clockwork Paradise', Decimal('0.99'), 'PG-13'),
#  (160, 'Club Graffiti', Decimal('0.99'), 'PG-13'),
#  (163, 'Clyde Theory', Decimal('0.99'), 'PG-13')]

# %% [markdown]
# The first condition filters out rows that have `rental_rate` less than 2.0. The second condition filters out rows that have the rating 'PG-13'. Combining both conditions with `and` operator will instruct the database to fetch only rows that meet *both* conditions. Let's see what happens if you change the operator from `and` to `or`:

# %%
# %%sql
#
# SELECT film_id, title, rental_rate, rating
# FROM film
# WHERE rental_rate < 2.0
# OR rating = 'PG-13' LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(98, 'Bright Encounters', Decimal('4.99'), 'PG-13'),
#  (1, 'Academy Dinosaur', Decimal('0.99'), 'PG'),
#  (7, 'Airplane Sierra', Decimal('4.99'), 'PG-13'),
#  (9, 'Alabama Devil', Decimal('2.99'), 'PG-13'),
#  (11, 'Alamo Videotape', Decimal('0.99'), 'G'),
#  (12, 'Alaska Phantom', Decimal('0.99'), 'PG'),
#  (213, 'Date Speed', Decimal('0.99'), 'R'),
#  (14, 'Alice Fantasia', Decimal('0.99'), 'NC-17'),
#  (17, 'Alone Trip', Decimal('0.99'), 'R'),
#  (18, 'Alter Victory', Decimal('0.99'), 'PG-13')]

# %% [markdown]
# Looking at the output, you will see that each row will have either rental_rate less than 2.0 or having the rating 'PG-13'. Thus at least one of the conditions is true for every row in the result set.
#
# You can also combine both `or` and `and` operators by using parentheses to group conditions together like this:

# %%
# %%sql
#
# SELECT film_id, title, rental_rate, rating
# FROM film
# WHERE (rental_rate < 2.0 AND rating = 'PG')
# OR (rental_rate > 2.0 AND rating = 'NC-17') LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(133, 'Chamber Italian', Decimal('4.99'), 'NC-17'),
#  (1, 'Academy Dinosaur', Decimal('0.99'), 'PG'),
#  (3, 'Adaptation Holes', Decimal('2.99'), 'NC-17'),
#  (10, 'Aladdin Calendar', Decimal('4.99'), 'NC-17'),
#  (12, 'Alaska Phantom', Decimal('0.99'), 'PG'),
#  (15, 'Alien Center', Decimal('2.99'), 'NC-17'),
#  (16, 'Alley Evolution', Decimal('2.99'), 'NC-17'),
#  (19, 'Amadeus Holy', Decimal('0.99'), 'PG'),
#  (29, 'Antitrust Tomatoes', Decimal('2.99'), 'NC-17'),
#  (31, 'Apache Divine', Decimal('4.99'), 'NC-17')]

# %% [markdown]
# ## The `group by` and `having` Clauses
#
# All of the queries thus far retrieve raw data without any manipulation. In some cases, you will want to find trends in your data that will require the database server to cook the data a bit before your retrieve your result set. One such mechanism is the `group by` clause, which is used to group data by column values. When using the `group by` clause, you may also use the `having` clause, which allows you to filter out group data in the same way the `where` clause lets you filter raw data. Consider this example where we like to query the number of customers each rental store has below:

# %%
# %%sql
#
# SELECT s.store_id, COUNT(c.customer_id) num_customers
# FROM store AS s INNER JOIN customer AS c
# ON s.store_id = c.store_id
# GROUP BY s.store_id
# HAVING count(c.customer_id) > 2;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 2 rows affected.
# [(1, 326), (2, 273)]

# %% [markdown]
# **Note:** The `COUNT()` is an aggregate in-built function that allows you to get the number of rows that match a specific condition of a query.

# %% [markdown]
# ## The `order by` Clause
#
# In general, the rows in a result set returned from a query are not in any particular order. If you want your result set in a particular order, you will need to instruct the server to sort the results using the `order by` clause.
#
# > *The `order by` clause is the mechanism for sorting your result set using either raw columnd data or expressions based on column data.*
#
# Let's look at the example below:

# %%
# %%sql
#
# SELECT customer_id, first_name, last_name
# FROM customer
# ORDER BY last_name
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(505, 'Rafael', 'Abney'),
#  (504, 'Nathaniel', 'Adam'),
#  (36, 'Kathleen', 'Adams'),
#  (96, 'Diana', 'Alexander'),
#  (470, 'Gordon', 'Allard'),
#  (27, 'Shirley', 'Allen'),
#  (220, 'Charlene', 'Alvarez'),
#  (11, 'Lisa', 'Anderson'),
#  (326, 'Jose', 'Andrew'),
#  (183, 'Ida', 'Andrews')]

# %% [markdown]
# ### Ascending Versus Descending Sort Order
#
# When using `order by`, you have the option of specifying *ascending* or *descending* order via the `asc` and `desc` keywords. The default is ascending. so you'll need to add the `desc` keyword, only if you want to use a descending sort, like in the example below:

# %%
# %%sql
#
# SELECT customer_id, first_name, last_name
# FROM customer
# ORDER BY last_name DESC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 10 rows affected.
# [(28, 'Cynthia', 'Young'),
#  (413, 'Marvin', 'Yee'),
#  (402, 'Luis', 'Yanez'),
#  (318, 'Brian', 'Wyman'),
#  (31, 'Brenda', 'Wright'),
#  (496, 'Tyler', 'Wren'),
#  (107, 'Florence', 'Woods'),
#  (78, 'Lori', 'Wood'),
#  (581, 'Virgil', 'Wofford'),
#  (541, 'Darren', 'Windham')]

# %%
# %%sql
#
# SELECT customer_id, email
# FROM customer;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
# 599 rows affected.
# [(524, 'jared.ely@sakilacustomer.org'),
#  (1, 'mary.smith@sakilacustomer.org'),
#  (2, 'patricia.johnson@sakilacustomer.org'),
#  (3, 'linda.williams@sakilacustomer.org'),
#  (4, 'barbara.jones@sakilacustomer.org'),
#  (5, 'elizabeth.brown@sakilacustomer.org'),
#  (6, 'jennifer.davis@sakilacustomer.org'),
#  (7, 'maria.miller@sakilacustomer.org'),
#  (8, 'susan.wilson@sakilacustomer.org'),
#  (9, 'margaret.moore@sakilacustomer.org'),
#  (10, 'dorothy.taylor@sakilacustomer.org'),
#  (11, 'lisa.anderson@sakilacustomer.org'),
#  (12, 'nancy.thomas@sakilacustomer.org'),
#  (13, 'karen.jackson@sakilacustomer.org'),
#  (14, 'betty.white@sakilacustomer.org'),
#  (15, 'helen.harris@sakilacustomer.org'),
#  (16, 'sandra.martin@sakilacustomer.org'),
#  (17, 'donna.thompson@sakilacustomer.org'),
#  (18, 'carol.garcia@sakilacustomer.org'),
#  (19, 'ruth.martinez@sakilacustomer.org'),
#  (20, 'sharon.robinson@sakilacustomer.org'),
#  (21, 'michelle.clark@sakilacustomer.org'),
#  (22, 'laura.rodriguez@sakilacustomer.org'),
#  (23, 'sarah.lewis@sakilacustomer.org'),
#  (24, 'kimberly.lee@sakilacustomer.org'),
#  (25, 'deborah.walker@sakilacustomer.org'),
#  (26, 'jessica.hall@sakilacustomer.org'),
#  (27, 'shirley.allen@sakilacustomer.org'),
#  (28, 'cynthia.young@sakilacustomer.org'),
#  (29, 'angela.hernandez@sakilacustomer.org'),
#  (30, 'melissa.king@sakilacustomer.org'),
#  (31, 'brenda.wright@sakilacustomer.org'),
#  (32, 'amy.lopez@sakilacustomer.org'),
#  (33, 'anna.hill@sakilacustomer.org'),
#  (34, 'rebecca.scott@sakilacustomer.org'),
#  (35, 'virginia.green@sakilacustomer.org'),
#  (36, 'kathleen.adams@sakilacustomer.org'),
#  (37, 'pamela.baker@sakilacustomer.org'),
#  (38, 'martha.gonzalez@sakilacustomer.org'),
#  (39, 'debra.nelson@sakilacustomer.org'),
#  (40, 'amanda.carter@sakilacustomer.org'),
#  (41, 'stephanie.mitchell@sakilacustomer.org'),
#  (42, 'carolyn.perez@sakilacustomer.org'),
#  (43, 'christine.roberts@sakilacustomer.org'),
#  (44, 'marie.turner@sakilacustomer.org'),
#  (45, 'janet.phillips@sakilacustomer.org'),
#  (46, 'catherine.campbell@sakilacustomer.org'),
#  (47, 'frances.parker@sakilacustomer.org'),
#  (48, 'ann.evans@sakilacustomer.org'),
#  (49, 'joyce.edwards@sakilacustomer.org'),
#  (50, 'diane.collins@sakilacustomer.org'),
#  (51, 'alice.stewart@sakilacustomer.org'),
#  (52, 'julie.sanchez@sakilacustomer.org'),
#  (53, 'heather.morris@sakilacustomer.org'),
#  (54, 'teresa.rogers@sakilacustomer.org'),
#  (55, 'doris.reed@sakilacustomer.org'),
#  (56, 'gloria.cook@sakilacustomer.org'),
#  (57, 'evelyn.morgan@sakilacustomer.org'),
#  (58, 'jean.bell@sakilacustomer.org'),
#  (59, 'cheryl.murphy@sakilacustomer.org'),
#  (60, 'mildred.bailey@sakilacustomer.org'),
#  (61, 'katherine.rivera@sakilacustomer.org'),
#  (62, 'joan.cooper@sakilacustomer.org'),
#  (63, 'ashley.richardson@sakilacustomer.org'),
#  (64, 'judith.cox@sakilacustomer.org'),
#  (65, 'rose.howard@sakilacustomer.org'),
#  (66, 'janice.ward@sakilacustomer.org'),
#  (67, 'kelly.torres@sakilacustomer.org'),
#  (68, 'nicole.peterson@sakilacustomer.org'),
#  (69, 'judy.gray@sakilacustomer.org'),
#  (70, 'christina.ramirez@sakilacustomer.org'),
#  (71, 'kathy.james@sakilacustomer.org'),
#  (72, 'theresa.watson@sakilacustomer.org'),
#  (73, 'beverly.brooks@sakilacustomer.org'),
#  (74, 'denise.kelly@sakilacustomer.org'),
#  (75, 'tammy.sanders@sakilacustomer.org'),
#  (76, 'irene.price@sakilacustomer.org'),
#  (77, 'jane.bennett@sakilacustomer.org'),
#  (78, 'lori.wood@sakilacustomer.org'),
#  (79, 'rachel.barnes@sakilacustomer.org'),
#  (80, 'marilyn.ross@sakilacustomer.org'),
#  (81, 'andrea.henderson@sakilacustomer.org'),
#  (82, 'kathryn.coleman@sakilacustomer.org'),
#  (83, 'louise.jenkins@sakilacustomer.org'),
#  (84, 'sara.perry@sakilacustomer.org'),
#  (85, 'anne.powell@sakilacustomer.org'),
#  (86, 'jacqueline.long@sakilacustomer.org'),
#  (87, 'wanda.patterson@sakilacustomer.org'),
#  (88, 'bonnie.hughes@sakilacustomer.org'),
#  (89, 'julia.flores@sakilacustomer.org'),
#  (90, 'ruby.washington@sakilacustomer.org'),
#  (91, 'lois.butler@sakilacustomer.org'),
#  (92, 'tina.simmons@sakilacustomer.org'),
#  (93, 'phyllis.foster@sakilacustomer.org'),
#  (94, 'norma.gonzales@sakilacustomer.org'),
#  (95, 'paula.bryant@sakilacustomer.org'),
#  (96, 'diana.alexander@sakilacustomer.org'),
#  (97, 'annie.russell@sakilacustomer.org'),
#  (98, 'lillian.griffin@sakilacustomer.org'),
#  (99, 'emily.diaz@sakilacustomer.org'),
#  (100, 'robin.hayes@sakilacustomer.org'),
#  (101, 'peggy.myers@sakilacustomer.org'),
#  (102, 'crystal.ford@sakilacustomer.org'),
#  (103, 'gladys.hamilton@sakilacustomer.org'),
#  (104, 'rita.graham@sakilacustomer.org'),
#  (105, 'dawn.sullivan@sakilacustomer.org'),
#  (106, 'connie.wallace@sakilacustomer.org'),
#  (107, 'florence.woods@sakilacustomer.org'),
#  (108, 'tracy.cole@sakilacustomer.org'),
#  (109, 'edna.west@sakilacustomer.org'),
#  (110, 'tiffany.jordan@sakilacustomer.org'),
#  (111, 'carmen.owens@sakilacustomer.org'),
#  (112, 'rosa.reynolds@sakilacustomer.org'),
#  (113, 'cindy.fisher@sakilacustomer.org'),
#  (114, 'grace.ellis@sakilacustomer.org'),
#  (115, 'wendy.harrison@sakilacustomer.org'),
#  (116, 'victoria.gibson@sakilacustomer.org'),
#  (117, 'edith.mcdonald@sakilacustomer.org'),
#  (118, 'kim.cruz@sakilacustomer.org'),
#  (119, 'sherry.marshall@sakilacustomer.org'),
#  (120, 'sylvia.ortiz@sakilacustomer.org'),
#  (121, 'josephine.gomez@sakilacustomer.org'),
#  (122, 'thelma.murray@sakilacustomer.org'),
#  (123, 'shannon.freeman@sakilacustomer.org'),
#  (124, 'sheila.wells@sakilacustomer.org'),
#  (125, 'ethel.webb@sakilacustomer.org'),
#  (126, 'ellen.simpson@sakilacustomer.org'),
#  (127, 'elaine.stevens@sakilacustomer.org'),
#  (128, 'marjorie.tucker@sakilacustomer.org'),
#  (129, 'carrie.porter@sakilacustomer.org'),
#  (130, 'charlotte.hunter@sakilacustomer.org'),
#  (131, 'monica.hicks@sakilacustomer.org'),
#  (132, 'esther.crawford@sakilacustomer.org'),
#  (133, 'pauline.henry@sakilacustomer.org'),
#  (134, 'emma.boyd@sakilacustomer.org'),
#  (135, 'juanita.mason@sakilacustomer.org'),
#  (136, 'anita.morales@sakilacustomer.org'),
#  (137, 'rhonda.kennedy@sakilacustomer.org'),
#  (138, 'hazel.warren@sakilacustomer.org'),
#  (139, 'amber.dixon@sakilacustomer.org'),
#  (140, 'eva.ramos@sakilacustomer.org'),
#  (141, 'debbie.reyes@sakilacustomer.org'),
#  (142, 'april.burns@sakilacustomer.org'),
#  (143, 'leslie.gordon@sakilacustomer.org'),
#  (144, 'clara.shaw@sakilacustomer.org'),
#  (145, 'lucille.holmes@sakilacustomer.org'),
#  (146, 'jamie.rice@sakilacustomer.org'),
#  (147, 'joanne.robertson@sakilacustomer.org'),
#  (148, 'eleanor.hunt@sakilacustomer.org'),
#  (149, 'valerie.black@sakilacustomer.org'),
#  (150, 'danielle.daniels@sakilacustomer.org'),
#  (151, 'megan.palmer@sakilacustomer.org'),
#  (152, 'alicia.mills@sakilacustomer.org'),
#  (153, 'suzanne.nichols@sakilacustomer.org'),
#  (154, 'michele.grant@sakilacustomer.org'),
#  (155, 'gail.knight@sakilacustomer.org'),
#  (156, 'bertha.ferguson@sakilacustomer.org'),
#  (157, 'darlene.rose@sakilacustomer.org'),
#  (158, 'veronica.stone@sakilacustomer.org'),
#  (159, 'jill.hawkins@sakilacustomer.org'),
#  (160, 'erin.dunn@sakilacustomer.org'),
#  (161, 'geraldine.perkins@sakilacustomer.org'),
#  (162, 'lauren.hudson@sakilacustomer.org'),
#  (163, 'cathy.spencer@sakilacustomer.org'),
#  (164, 'joann.gardner@sakilacustomer.org'),
#  (165, 'lorraine.stephens@sakilacustomer.org'),
#  (166, 'lynn.payne@sakilacustomer.org'),
#  (167, 'sally.pierce@sakilacustomer.org'),
#  (168, 'regina.berry@sakilacustomer.org'),
#  (169, 'erica.matthews@sakilacustomer.org'),
#  (170, 'beatrice.arnold@sakilacustomer.org'),
#  (171, 'dolores.wagner@sakilacustomer.org'),
#  (172, 'bernice.willis@sakilacustomer.org'),
#  (173, 'audrey.ray@sakilacustomer.org'),
#  (174, 'yvonne.watkins@sakilacustomer.org'),
#  (175, 'annette.olson@sakilacustomer.org'),
#  (176, 'june.carroll@sakilacustomer.org'),
#  (177, 'samantha.duncan@sakilacustomer.org'),
#  (178, 'marion.snyder@sakilacustomer.org'),
#  (179, 'dana.hart@sakilacustomer.org'),
#  (180, 'stacy.cunningham@sakilacustomer.org'),
#  (181, 'ana.bradley@sakilacustomer.org'),
#  (182, 'renee.lane@sakilacustomer.org'),
#  (183, 'ida.andrews@sakilacustomer.org'),
#  (184, 'vivian.ruiz@sakilacustomer.org'),
#  (185, 'roberta.harper@sakilacustomer.org'),
#  (186, 'holly.fox@sakilacustomer.org'),
#  (187, 'brittany.riley@sakilacustomer.org'),
#  (188, 'melanie.armstrong@sakilacustomer.org'),
#  (189, 'loretta.carpenter@sakilacustomer.org'),
#  (190, 'yolanda.weaver@sakilacustomer.org'),
#  (191, 'jeanette.greene@sakilacustomer.org'),
#  (192, 'laurie.lawrence@sakilacustomer.org'),
#  (193, 'katie.elliott@sakilacustomer.org'),
#  (194, 'kristen.chavez@sakilacustomer.org'),
#  (195, 'vanessa.sims@sakilacustomer.org'),
#  (196, 'alma.austin@sakilacustomer.org'),
#  (197, 'sue.peters@sakilacustomer.org'),
#  (198, 'elsie.kelley@sakilacustomer.org'),
#  (199, 'beth.franklin@sakilacustomer.org'),
#  (200, 'jeanne.lawson@sakilacustomer.org'),
#  (201, 'vicki.fields@sakilacustomer.org'),
#  (202, 'carla.gutierrez@sakilacustomer.org'),
#  (203, 'tara.ryan@sakilacustomer.org'),
#  (204, 'rosemary.schmidt@sakilacustomer.org'),
#  (205, 'eileen.carr@sakilacustomer.org'),
#  (206, 'terri.vasquez@sakilacustomer.org'),
#  (207, 'gertrude.castillo@sakilacustomer.org'),
#  (208, 'lucy.wheeler@sakilacustomer.org'),
#  (209, 'tonya.chapman@sakilacustomer.org'),
#  (210, 'ella.oliver@sakilacustomer.org'),
#  (211, 'stacey.montgomery@sakilacustomer.org'),
#  (212, 'wilma.richards@sakilacustomer.org'),
#  (213, 'gina.williamson@sakilacustomer.org'),
#  (214, 'kristin.johnston@sakilacustomer.org'),
#  (215, 'jessie.banks@sakilacustomer.org'),
#  (216, 'natalie.meyer@sakilacustomer.org'),
#  (217, 'agnes.bishop@sakilacustomer.org'),
#  (218, 'vera.mccoy@sakilacustomer.org'),
#  (219, 'willie.howell@sakilacustomer.org'),
#  (220, 'charlene.alvarez@sakilacustomer.org'),
#  (221, 'bessie.morrison@sakilacustomer.org'),
#  (222, 'delores.hansen@sakilacustomer.org'),
#  (223, 'melinda.fernandez@sakilacustomer.org'),
#  (224, 'pearl.garza@sakilacustomer.org'),
#  (225, 'arlene.harvey@sakilacustomer.org'),
#  (226, 'maureen.little@sakilacustomer.org'),
#  (227, 'colleen.burton@sakilacustomer.org'),
#  (228, 'allison.stanley@sakilacustomer.org'),
#  (229, 'tamara.nguyen@sakilacustomer.org'),
#  (230, 'joy.george@sakilacustomer.org'),
#  (231, 'georgia.jacobs@sakilacustomer.org'),
#  (232, 'constance.reid@sakilacustomer.org'),
#  (233, 'lillie.kim@sakilacustomer.org'),
#  (234, 'claudia.fuller@sakilacustomer.org'),
#  (235, 'jackie.lynch@sakilacustomer.org'),
#  (236, 'marcia.dean@sakilacustomer.org'),
#  (237, 'tanya.gilbert@sakilacustomer.org'),
#  (238, 'nellie.garrett@sakilacustomer.org'),
#  (239, 'minnie.romero@sakilacustomer.org'),
#  (240, 'marlene.welch@sakilacustomer.org'),
#  (241, 'heidi.larson@sakilacustomer.org'),
#  (242, 'glenda.frazier@sakilacustomer.org'),
#  (243, 'lydia.burke@sakilacustomer.org'),
#  (244, 'viola.hanson@sakilacustomer.org'),
#  (245, 'courtney.day@sakilacustomer.org'),
#  (246, 'marian.mendoza@sakilacustomer.org'),
#  (247, 'stella.moreno@sakilacustomer.org'),
#  (248, 'caroline.bowman@sakilacustomer.org'),
#  (249, 'dora.medina@sakilacustomer.org'),
#  (250, 'jo.fowler@sakilacustomer.org'),
#  (251, 'vickie.brewer@sakilacustomer.org'),
#  (252, 'mattie.hoffman@sakilacustomer.org'),
#  (253, 'terry.carlson@sakilacustomer.org'),
#  (254, 'maxine.silva@sakilacustomer.org'),
#  (255, 'irma.pearson@sakilacustomer.org'),
#  (256, 'mabel.holland@sakilacustomer.org'),
#  (257, 'marsha.douglas@sakilacustomer.org'),
#  (258, 'myrtle.fleming@sakilacustomer.org'),
#  (259, 'lena.jensen@sakilacustomer.org'),
#  (260, 'christy.vargas@sakilacustomer.org'),
#  (261, 'deanna.byrd@sakilacustomer.org'),
#  (262, 'patsy.davidson@sakilacustomer.org'),
#  (263, 'hilda.hopkins@sakilacustomer.org'),
#  (264, 'gwendolyn.may@sakilacustomer.org'),
#  (265, 'jennie.terry@sakilacustomer.org'),
#  (266, 'nora.herrera@sakilacustomer.org'),
#  (267, 'margie.wade@sakilacustomer.org'),
#  (268, 'nina.soto@sakilacustomer.org'),
#  (269, 'cassandra.walters@sakilacustomer.org'),
#  (270, 'leah.curtis@sakilacustomer.org'),
#  (271, 'penny.neal@sakilacustomer.org'),
#  (272, 'kay.caldwell@sakilacustomer.org'),
#  (273, 'priscilla.lowe@sakilacustomer.org'),
#  (274, 'naomi.jennings@sakilacustomer.org'),
#  (275, 'carole.barnett@sakilacustomer.org'),
#  (276, 'brandy.graves@sakilacustomer.org'),
#  (277, 'olga.jimenez@sakilacustomer.org'),
#  (278, 'billie.horton@sakilacustomer.org'),
#  (279, 'dianne.shelton@sakilacustomer.org'),
#  (280, 'tracey.barrett@sakilacustomer.org'),
#  (281, 'leona.obrien@sakilacustomer.org'),
#  (282, 'jenny.castro@sakilacustomer.org'),
#  (283, 'felicia.sutton@sakilacustomer.org'),
#  (284, 'sonia.gregory@sakilacustomer.org'),
#  (285, 'miriam.mckinney@sakilacustomer.org'),
#  (286, 'velma.lucas@sakilacustomer.org'),
#  (287, 'becky.miles@sakilacustomer.org'),
#  (288, 'bobbie.craig@sakilacustomer.org'),
#  (289, 'violet.rodriquez@sakilacustomer.org'),
#  (290, 'kristina.chambers@sakilacustomer.org'),
#  (291, 'toni.holt@sakilacustomer.org'),
#  (292, 'misty.lambert@sakilacustomer.org'),
#  (293, 'mae.fletcher@sakilacustomer.org'),
#  (294, 'shelly.watts@sakilacustomer.org'),
#  (295, 'daisy.bates@sakilacustomer.org'),
#  (296, 'ramona.hale@sakilacustomer.org'),
#  (297, 'sherri.rhodes@sakilacustomer.org'),
#  (298, 'erika.pena@sakilacustomer.org'),
#  (299, 'james.gannon@sakilacustomer.org'),
#  (300, 'john.farnsworth@sakilacustomer.org'),
#  (301, 'robert.baughman@sakilacustomer.org'),
#  (302, 'michael.silverman@sakilacustomer.org'),
#  (303, 'william.satterfield@sakilacustomer.org'),
#  (304, 'david.royal@sakilacustomer.org'),
#  (305, 'richard.mccrary@sakilacustomer.org'),
#  (306, 'charles.kowalski@sakilacustomer.org'),
#  (307, 'joseph.joy@sakilacustomer.org'),
#  (308, 'thomas.grigsby@sakilacustomer.org'),
#  (309, 'christopher.greco@sakilacustomer.org'),
#  (310, 'daniel.cabral@sakilacustomer.org'),
#  (311, 'paul.trout@sakilacustomer.org'),
#  (312, 'mark.rinehart@sakilacustomer.org'),
#  (313, 'donald.mahon@sakilacustomer.org'),
#  (314, 'george.linton@sakilacustomer.org'),
#  (315, 'kenneth.gooden@sakilacustomer.org'),
#  (316, 'steven.curley@sakilacustomer.org'),
#  (317, 'edward.baugh@sakilacustomer.org'),
#  (318, 'brian.wyman@sakilacustomer.org'),
#  (319, 'ronald.weiner@sakilacustomer.org'),
#  (320, 'anthony.schwab@sakilacustomer.org'),
#  (321, 'kevin.schuler@sakilacustomer.org'),
#  (322, 'jason.morrissey@sakilacustomer.org'),
#  (323, 'matthew.mahan@sakilacustomer.org'),
#  (324, 'gary.coy@sakilacustomer.org'),
#  (325, 'timothy.bunn@sakilacustomer.org'),
#  (326, 'jose.andrew@sakilacustomer.org'),
#  (327, 'larry.thrasher@sakilacustomer.org'),
#  (328, 'jeffrey.spear@sakilacustomer.org'),
#  (329, 'frank.waggoner@sakilacustomer.org'),
#  (330, 'scott.shelley@sakilacustomer.org'),
#  (331, 'eric.robert@sakilacustomer.org'),
#  (332, 'stephen.qualls@sakilacustomer.org'),
#  (333, 'andrew.purdy@sakilacustomer.org'),
#  (334, 'raymond.mcwhorter@sakilacustomer.org'),
#  (335, 'gregory.mauldin@sakilacustomer.org'),
#  (336, 'joshua.mark@sakilacustomer.org'),
#  (337, 'jerry.jordon@sakilacustomer.org'),
#  (338, 'dennis.gilman@sakilacustomer.org'),
#  (339, 'walter.perryman@sakilacustomer.org'),
#  (340, 'patrick.newsom@sakilacustomer.org'),
#  (341, 'peter.menard@sakilacustomer.org'),
#  (342, 'harold.martino@sakilacustomer.org'),
#  (343, 'douglas.graf@sakilacustomer.org'),
#  (344, 'henry.billingsley@sakilacustomer.org'),
#  (345, 'carl.artis@sakilacustomer.org'),
#  (346, 'arthur.simpkins@sakilacustomer.org'),
#  (347, 'ryan.salisbury@sakilacustomer.org'),
#  (348, 'roger.quintanilla@sakilacustomer.org'),
#  (349, 'joe.gilliland@sakilacustomer.org'),
#  (350, 'juan.fraley@sakilacustomer.org'),
#  (351, 'jack.foust@sakilacustomer.org'),
#  (352, 'albert.crouse@sakilacustomer.org'),
#  (353, 'jonathan.scarborough@sakilacustomer.org'),
#  (354, 'justin.ngo@sakilacustomer.org'),
#  (355, 'terry.grissom@sakilacustomer.org'),
#  (356, 'gerald.fultz@sakilacustomer.org'),
#  (357, 'keith.rico@sakilacustomer.org'),
#  (358, 'samuel.marlow@sakilacustomer.org'),
#  (359, 'willie.markham@sakilacustomer.org'),
#  (360, 'ralph.madrigal@sakilacustomer.org'),
#  (361, 'lawrence.lawton@sakilacustomer.org'),
#  (362, 'nicholas.barfield@sakilacustomer.org'),
#  (363, 'roy.whiting@sakilacustomer.org'),
#  (364, 'benjamin.varney@sakilacustomer.org'),
#  (365, 'bruce.schwarz@sakilacustomer.org'),
#  (366, 'brandon.huey@sakilacustomer.org'),
#  (367, 'adam.gooch@sakilacustomer.org'),
#  (368, 'harry.arce@sakilacustomer.org'),
#  (369, 'fred.wheat@sakilacustomer.org'),
#  (370, 'wayne.truong@sakilacustomer.org'),
#  (371, 'billy.poulin@sakilacustomer.org'),
#  (372, 'steve.mackenzie@sakilacustomer.org'),
#  (373, 'louis.leone@sakilacustomer.org'),
#  (374, 'jeremy.hurtado@sakilacustomer.org'),
#  (375, 'aaron.selby@sakilacustomer.org'),
#  (376, 'randy.gaither@sakilacustomer.org'),
#  (377, 'howard.fortner@sakilacustomer.org'),
#  (378, 'eugene.culpepper@sakilacustomer.org'),
#  (379, 'carlos.coughlin@sakilacustomer.org'),
#  (380, 'russell.brinson@sakilacustomer.org'),
#  (381, 'bobby.boudreau@sakilacustomer.org'),
#  (382, 'victor.barkley@sakilacustomer.org'),
#  (383, 'martin.bales@sakilacustomer.org'),
#  (384, 'ernest.stepp@sakilacustomer.org'),
#  (385, 'phillip.holm@sakilacustomer.org'),
#  (386, 'todd.tan@sakilacustomer.org'),
#  (387, 'jesse.schilling@sakilacustomer.org'),
#  (388, 'craig.morrell@sakilacustomer.org'),
#  (389, 'alan.kahn@sakilacustomer.org'),
#  (390, 'shawn.heaton@sakilacustomer.org'),
#  (391, 'clarence.gamez@sakilacustomer.org'),
#  (392, 'sean.douglass@sakilacustomer.org'),
#  (393, 'philip.causey@sakilacustomer.org'),
#  (394, 'chris.brothers@sakilacustomer.org'),
#  (395, 'johnny.turpin@sakilacustomer.org'),
#  (396, 'earl.shanks@sakilacustomer.org'),
#  (397, 'jimmy.schrader@sakilacustomer.org'),
#  (398, 'antonio.meek@sakilacustomer.org'),
#  (399, 'danny.isom@sakilacustomer.org'),
#  (400, 'bryan.hardison@sakilacustomer.org'),
#  (401, 'tony.carranza@sakilacustomer.org'),
#  (402, 'luis.yanez@sakilacustomer.org'),
#  (403, 'mike.way@sakilacustomer.org'),
#  (404, 'stanley.scroggins@sakilacustomer.org'),
#  (405, 'leonard.schofield@sakilacustomer.org'),
#  (406, 'nathan.runyon@sakilacustomer.org'),
#  (407, 'dale.ratcliff@sakilacustomer.org'),
#  (408, 'manuel.murrell@sakilacustomer.org'),
#  (409, 'rodney.moeller@sakilacustomer.org'),
#  (410, 'curtis.irby@sakilacustomer.org'),
#  (411, 'norman.currier@sakilacustomer.org'),
#  (412, 'allen.butterfield@sakilacustomer.org'),
#  (413, 'marvin.yee@sakilacustomer.org'),
#  (414, 'vincent.ralston@sakilacustomer.org'),
#  (415, 'glenn.pullen@sakilacustomer.org'),
#  (416, 'jeffery.pinson@sakilacustomer.org'),
#  (417, 'travis.estep@sakilacustomer.org'),
#  (418, 'jeff.east@sakilacustomer.org'),
#  (419, 'chad.carbone@sakilacustomer.org'),
#  (420, 'jacob.lance@sakilacustomer.org'),
#  (421, 'lee.hawks@sakilacustomer.org'),
#  (422, 'melvin.ellington@sakilacustomer.org'),
#  (423, 'alfred.casillas@sakilacustomer.org'),
#  (424, 'kyle.spurlock@sakilacustomer.org'),
#  (425, 'francis.sikes@sakilacustomer.org'),
#  (426, 'bradley.motley@sakilacustomer.org'),
#  (427, 'jesus.mccartney@sakilacustomer.org'),
#  (428, 'herbert.kruger@sakilacustomer.org'),
#  (429, 'frederick.isbell@sakilacustomer.org'),
#  (430, 'ray.houle@sakilacustomer.org'),
#  (431, 'joel.francisco@sakilacustomer.org'),
#  (432, 'edwin.burk@sakilacustomer.org'),
#  (433, 'don.bone@sakilacustomer.org'),
#  (434, 'eddie.tomlin@sakilacustomer.org'),
#  (435, 'ricky.shelby@sakilacustomer.org'),
#  (436, 'troy.quigley@sakilacustomer.org'),
#  (437, 'randall.neumann@sakilacustomer.org'),
#  (438, 'barry.lovelace@sakilacustomer.org'),
#  (439, 'alexander.fennell@sakilacustomer.org'),
#  (440, 'bernard.colby@sakilacustomer.org'),
#  (441, 'mario.cheatham@sakilacustomer.org'),
#  (442, 'leroy.bustamante@sakilacustomer.org'),
#  (443, 'francisco.skidmore@sakilacustomer.org'),
#  (444, 'marcus.hidalgo@sakilacustomer.org'),
#  (445, 'micheal.forman@sakilacustomer.org'),
#  (446, 'theodore.culp@sakilacustomer.org'),
#  (447, 'clifford.bowens@sakilacustomer.org'),
#  (448, 'miguel.betancourt@sakilacustomer.org'),
#  (449, 'oscar.aquino@sakilacustomer.org'),
#  (450, 'jay.robb@sakilacustomer.org'),
#  (451, 'jim.rea@sakilacustomer.org'),
#  (452, 'tom.milner@sakilacustomer.org'),
#  (453, 'calvin.martel@sakilacustomer.org'),
#  (454, 'alex.gresham@sakilacustomer.org'),
#  (455, 'jon.wiles@sakilacustomer.org'),
#  (456, 'ronnie.ricketts@sakilacustomer.org'),
#  (457, 'bill.gavin@sakilacustomer.org'),
#  (458, 'lloyd.dowd@sakilacustomer.org'),
#  (459, 'tommy.collazo@sakilacustomer.org'),
#  (460, 'leon.bostic@sakilacustomer.org'),
#  (461, 'derek.blakely@sakilacustomer.org'),
#  (462, 'warren.sherrod@sakilacustomer.org'),
#  (463, 'darrell.power@sakilacustomer.org'),
#  (464, 'jerome.kenyon@sakilacustomer.org'),
#  (465, 'floyd.gandy@sakilacustomer.org'),
#  (466, 'leo.ebert@sakilacustomer.org'),
#  (467, 'alvin.deloach@sakilacustomer.org'),
#  (468, 'tim.cary@sakilacustomer.org'),
#  (469, 'wesley.bull@sakilacustomer.org'),
#  (470, 'gordon.allard@sakilacustomer.org'),
#  (471, 'dean.sauer@sakilacustomer.org'),
#  (472, 'greg.robins@sakilacustomer.org'),
#  (473, 'jorge.olivares@sakilacustomer.org'),
#  (474, 'dustin.gillette@sakilacustomer.org'),
#  (475, 'pedro.chestnut@sakilacustomer.org'),
#  (476, 'derrick.bourque@sakilacustomer.org'),
#  (477, 'dan.paine@sakilacustomer.org'),
#  (478, 'lewis.lyman@sakilacustomer.org'),
#  (479, 'zachary.hite@sakilacustomer.org'),
#  (480, 'corey.hauser@sakilacustomer.org'),
#  (481, 'herman.devore@sakilacustomer.org'),
#  (482, 'maurice.crawley@sakilacustomer.org'),
#  (483, 'vernon.chapa@sakilacustomer.org'),
#  (484, 'roberto.vu@sakilacustomer.org'),
#  (485, 'clyde.tobias@sakilacustomer.org'),
#  (486, 'glen.talbert@sakilacustomer.org'),
#  (487, 'hector.poindexter@sakilacustomer.org'),
#  (488, 'shane.millard@sakilacustomer.org'),
#  (489, 'ricardo.meador@sakilacustomer.org'),
#  (490, 'sam.mcduffie@sakilacustomer.org'),
#  (491, 'rick.mattox@sakilacustomer.org'),
#  (492, 'lester.kraus@sakilacustomer.org'),
#  (493, 'brent.harkins@sakilacustomer.org'),
#  (494, 'ramon.choate@sakilacustomer.org'),
#  (495, 'charlie.bess@sakilacustomer.org'),
#  (496, 'tyler.wren@sakilacustomer.org'),
#  (497, 'gilbert.sledge@sakilacustomer.org'),
#  (498, 'gene.sanborn@sakilacustomer.org'),
#  (499, 'marc.outlaw@sakilacustomer.org'),
#  (500, 'reginald.kinder@sakilacustomer.org'),
#  (501, 'ruben.geary@sakilacustomer.org'),
#  (502, 'brett.cornwell@sakilacustomer.org'),
#  (503, 'angel.barclay@sakilacustomer.org'),
#  (504, 'nathaniel.adam@sakilacustomer.org'),
#  (505, 'rafael.abney@sakilacustomer.org'),
#  (506, 'leslie.seward@sakilacustomer.org'),
#  (507, 'edgar.rhoads@sakilacustomer.org'),
#  (508, 'milton.howland@sakilacustomer.org'),
#  (509, 'raul.fortier@sakilacustomer.org'),
#  (510, 'ben.easter@sakilacustomer.org'),
#  (511, 'chester.benner@sakilacustomer.org'),
#  (512, 'cecil.vines@sakilacustomer.org'),
#  (513, 'duane.tubbs@sakilacustomer.org'),
#  (514, 'franklin.troutman@sakilacustomer.org'),
#  (515, 'andre.rapp@sakilacustomer.org'),
#  (516, 'elmer.noe@sakilacustomer.org'),
#  (517, 'brad.mccurdy@sakilacustomer.org'),
#  (518, 'gabriel.harder@sakilacustomer.org'),
#  (519, 'ron.deluca@sakilacustomer.org'),
#  (520, 'mitchell.westmoreland@sakilacustomer.org'),
#  (521, 'roland.south@sakilacustomer.org'),
#  (522, 'arnold.havens@sakilacustomer.org'),
#  (523, 'harvey.guajardo@sakilacustomer.org'),
#  (525, 'adrian.clary@sakilacustomer.org'),
#  (526, 'karl.seal@sakilacustomer.org'),
#  (527, 'cory.meehan@sakilacustomer.org'),
#  (528, 'claude.herzog@sakilacustomer.org'),
#  (529, 'erik.guillen@sakilacustomer.org'),
#  (530, 'darryl.ashcraft@sakilacustomer.org'),
#  (531, 'jamie.waugh@sakilacustomer.org'),
#  (532, 'neil.renner@sakilacustomer.org'),
#  (533, 'jessie.milam@sakilacustomer.org'),
#  (534, 'christian.jung@sakilacustomer.org'),
#  (535, 'javier.elrod@sakilacustomer.org'),
#  (536, 'fernando.churchill@sakilacustomer.org'),
#  (537, 'clinton.buford@sakilacustomer.org'),
#  (538, 'ted.breaux@sakilacustomer.org'),
#  (539, 'mathew.bolin@sakilacustomer.org'),
#  (540, 'tyrone.asher@sakilacustomer.org'),
#  (541, 'darren.windham@sakilacustomer.org'),
#  (542, 'lonnie.tirado@sakilacustomer.org'),
#  (543, 'lance.pemberton@sakilacustomer.org'),
#  (544, 'cody.nolen@sakilacustomer.org'),
#  (545, 'julio.noland@sakilacustomer.org'),
#  (546, 'kelly.knott@sakilacustomer.org'),
#  (547, 'kurt.emmons@sakilacustomer.org'),
#  (548, 'allan.cornish@sakilacustomer.org'),
#  (549, 'nelson.christenson@sakilacustomer.org'),
#  (550, 'guy.brownlee@sakilacustomer.org'),
#  (551, 'clayton.barbee@sakilacustomer.org'),
#  (552, 'hugh.waldrop@sakilacustomer.org'),
#  (553, 'max.pitt@sakilacustomer.org'),
#  (554, 'dwayne.olvera@sakilacustomer.org'),
#  (555, 'dwight.lombardi@sakilacustomer.org'),
#  (556, 'armando.gruber@sakilacustomer.org'),
#  (557, 'felix.gaffney@sakilacustomer.org'),
#  (558, 'jimmie.eggleston@sakilacustomer.org'),
#  (559, 'everett.banda@sakilacustomer.org'),
#  (560, 'jordan.archuleta@sakilacustomer.org'),
#  (561, 'ian.still@sakilacustomer.org'),
#  (562, 'wallace.slone@sakilacustomer.org'),
#  (563, 'ken.prewitt@sakilacustomer.org'),
#  (564, 'bob.pfeiffer@sakilacustomer.org'),
#  (565, 'jaime.nettles@sakilacustomer.org'),
#  (566, 'casey.mena@sakilacustomer.org'),
#  (567, 'alfredo.mcadams@sakilacustomer.org'),
#  (568, 'alberto.henning@sakilacustomer.org'),
#  (569, 'dave.gardiner@sakilacustomer.org'),
#  (570, 'ivan.cromwell@sakilacustomer.org'),
#  (571, 'johnnie.chisholm@sakilacustomer.org'),
#  (572, 'sidney.burleson@sakilacustomer.org'),
#  (573, 'byron.box@sakilacustomer.org'),
#  (574, 'julian.vest@sakilacustomer.org'),
#  (575, 'isaac.oglesby@sakilacustomer.org'),
#  (576, 'morris.mccarter@sakilacustomer.org'),
#  (577, 'clifton.malcolm@sakilacustomer.org'),
#  (578, 'willard.lumpkin@sakilacustomer.org'),
#  (579, 'daryl.larue@sakilacustomer.org'),
#  (580, 'ross.grey@sakilacustomer.org'),
#  (581, 'virgil.wofford@sakilacustomer.org'),
#  (582, 'andy.vanhorn@sakilacustomer.org'),
#  (583, 'marshall.thorn@sakilacustomer.org'),
#  (584, 'salvador.teel@sakilacustomer.org'),
#  (585, 'perry.swafford@sakilacustomer.org'),
#  (586, 'kirk.stclair@sakilacustomer.org'),
#  (587, 'sergio.stanfield@sakilacustomer.org'),
#  (588, 'marion.ocampo@sakilacustomer.org'),
#  (589, 'tracy.herrmann@sakilacustomer.org'),
#  (590, 'seth.hannon@sakilacustomer.org'),
#  (591, 'kent.arsenault@sakilacustomer.org'),
#  (592, 'terrance.roush@sakilacustomer.org'),
#  (593, 'rene.mcalister@sakilacustomer.org'),
#  (594, 'eduardo.hiatt@sakilacustomer.org'),
#  (595, 'terrence.gunderson@sakilacustomer.org'),
#  (596, 'enrique.forsythe@sakilacustomer.org'),
#  (597, 'freddie.duggan@sakilacustomer.org'),
#  (598, 'wade.delvalle@sakilacustomer.org'),
#  (599, 'austin.cintron@sakilacustomer.org')]
